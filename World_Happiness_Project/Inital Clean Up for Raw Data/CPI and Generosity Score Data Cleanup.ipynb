# %%
#!pip install xlrd - Harry Bonsu

# %%
import pandas as pd

# %%
cpi_global = pd.read_excel('../raw data/CPI2019.xlsx', engine='xlrd')

# %%
cpi_global
# Out:
#          Country ISO3 Region  CPI score 2020  Rank 2020  Sources 2020  \
# 0        Denmark  DNK  WE/EU              88          1             8
# 1    New Zealand  NZL     AP              88          1             8
# 2        Finland  FIN  WE/EU              85          3             8
# 3      Singapore  SGP     AP              85          3             9
# 4         Sweden  SWE  WE/EU              85          3             8
# ..           ...  ...    ...             ...        ...           ...
# 175    Venezuela  VEN    AME              15        176             8
# 176        Yemen  YEM   MENA              15        176             7
# 177        Syria  SYR   MENA              14        178             5
# 178      Somalia  SOM    SSA              12        179             6
# 179  South Sudan  SSD    SSA              12        179             5
#
#      Standard error 2020  CPI score 2019  Rank 2019  Sources 2019  ...  \
# ...

# %%
cpi_2019 = cpi_global[['Country', 'Region', 'CPI score 2019']]
cpi_2019
# Out:
#          Country Region  CPI score 2019
# 0        Denmark  WE/EU              87
# 1    New Zealand     AP              87
# 2        Finland  WE/EU              86
# 3      Singapore     AP              85
# 4         Sweden  WE/EU              85
# ..           ...    ...             ...
# 175    Venezuela    AME              16
# 176        Yemen   MENA              15
# 177        Syria   MENA              13
# 178      Somalia    SSA               9
# 179  South Sudan    SSA              12
#
# [180 rows x 3 columns]

# %%
#cpi_2019.to_csv("cpi_2019.csv")

# %%
global_giving = pd.read_json("data.json")
global_giving
# Out:
#            country  overallRank  overallScore  donateScore  helpStrangerScore  \
# 0          Myanmar            2            58           81                 49
# 1    United States            1            58           61                 72
# 2      New Zealand            3            57           65                 64
# 3          Ireland            5            56           69                 62
# 4        Australia            4            56           68                 64
# ..             ...          ...           ...          ...                ...
# 122       Bulgaria          120            19           16                 36
# 123         Serbia          123            19           22                 28
# 124          Yemen          124            17            6                 41
# 125         Greece          125            16            7                 36
# 126          China          126            16           11                 31
#
#      volTimeScore
# ...

# %%
global_generosity_score = global_giving[['country', 'overallScore']]
global_generosity_score
# Out:
#            country  overallScore
# 0          Myanmar            58
# 1    United States            58
# 2      New Zealand            57
# 3          Ireland            56
# 4        Australia            56
# ..             ...           ...
# 122       Bulgaria            19
# 123         Serbia            19
# 124          Yemen            17
# 125         Greece            16
# 126          China            16
#
# [127 rows x 2 columns]

# %%
#global_generosity_score.to_csv("global_generosity_score.csv", index=False)
